# %% [markdown]
# ## 1) Get the data: SDSS spectra and class labels
# <img src="https://www.sdss.org/wp-content/uploads/2014/11/SDSS_telescope_new.jpg" width=500 />
# The Sloan Digital Sky Survey (SDSS) is a full-sky survey that has been running at Apache Point Observatory since 2000. Up-to-date information can be found here: https://www.sdss.org/.
# In this tutorial we will use spectra taken with spectroscopic plates as shown below. See http://voyages.sdss.org/preflight/sdss-plates/ for more information on these.
# <img src="https://www.sdss.org/wp-content/uploads/2019/11/apogeen-plugging.png" width=300 />

# %%
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np
import os
import csv
import tensorflow as tf

data_path = 'data_spectra/'

# list of flux values, labels, and wavelength values
data = np.load(data_path + "data.npy")
labels = np.load(data_path + "labels.npy")
wavelengths = np.load(data_path + "wavelengths.npy")
print(np.shape(data))

# list number of objects
numbers = range(np.shape(data)[0])
# datapoints per spectrum
wave_shape = np.shape(data)[1]
# Out:
# (7000, 3522)

# %% [markdown]
# ## 2) Plot our spectra

# %%
for i in [1, 2, 3, 1002, 1534, 1550, 3500,3501,3502,3506,3508,3999]: # some example spectra
    plt.plot(wavelengths, data[i]) 
    plt.xlabel('wavelength(Å)') 
    plt.ylabel('flux (10-17 erg/s/cm2/Å)') 
    # 10^7 erg = 1 Joule (energy)
    plt.grid(True)
    plt.title(str(i))
    plt.show()

# %% [markdown]
# ## 3) Create training and test data set

# %%
import random

# shuffle the data
z = list(zip(data, labels, numbers)) 
random.shuffle(z)
data_shuffled, labels_shuffled, numbers_shuffled = zip(*z)

print(np.array(data_shuffled).shape)
print(np.array(labels_shuffled).shape)
# Out:
# (7000, 3522)
# (7000,)

# %%
# test and training split
percent_split = 0.9
split_index = int(len(data_shuffled)*percent_split)

# Flux
data_training = np.asarray(data_shuffled[:split_index])
data_test = np.asarray(data_shuffled[split_index:])

# Labels
labels_training = np.asarray(labels_shuffled[:split_index])
labels_test = np.asarray(labels_shuffled[split_index:])

# Number
numbers_training = numbers_shuffled[:split_index]
numbers_test = numbers_shuffled[split_index:]

# %%
# reshape training and test set
input_shape = (wave_shape,1)

data_training_r = np.reshape(data_training, newshape=(len(data_training), input_shape[0], input_shape[1]))
data_test_r  = np.reshape(data_test, newshape=(len(data_test), input_shape[0], input_shape[1]))

print(data_training_r.shape)
print(data_test_r.shape)
# Out:
# (6300, 3522, 1)
# (700, 3522, 1)

# %%
# further set-up of training and test data, optional normalization
do_normalize = True

if do_normalize:
    # L2-normalization (i.e. the sum of squared of elements is set equal to one)
    x_train = tf.keras.utils.normalize(data_training_r, axis=1)
    x_test = tf.keras.utils.normalize(data_test_r, axis=1)
else:
    x_train = data_training_r
    x_test = data_test_r

y_train = labels_training
y_test = labels_test

# %% [markdown]
# ## 4) Create the network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Flatten, Conv1D, MaxPooling1D, Dropout, InputLayer, GlobalAveragePooling1D
from tensorflow.keras.metrics import Accuracy
from tensorflow import keras
from tensorflow.keras import layers

# %%
# create network model
# example - try out what happens if you alter different hyperparameters

no_filter = 32
kernel_size = 20
strides = 10
dropout = 0.35
pooling = 3

# our model or architecture
model = tf.keras.Sequential([
    # add convolutional layer
    Conv1D(filters=no_filter, kernel_size=kernel_size, strides=strides, activation='relu', input_shape=input_shape), # stride
    # max-pooling against overfitting
    MaxPooling1D(pooling), 
    # dropout against overfitting
    Dropout(dropout), 
    # add convolutional layer
    Conv1D(filters=2*no_filter, kernel_size=2*kernel_size, strides=strides, activation='relu'),
    # max-pooling against overfitting
    MaxPooling1D(pooling),
    # dropout against overfitting
    Dropout(dropout),
    # flatten to feed into dense layers
    Flatten(),
    # Adds a densely-connected layer
    Dense(units=128, activation='relu'), # units = dimensionality of output
    # dropout again
    Dropout(dropout),
    # Add another dense layer, now a softmax (probability of different classes as the output)
    Dense(units=4, activation='softmax')
])

# %%
# compile the network model, choose optimiser, loss-function etc.
model.compile(optimizer='Adam', 
              loss='sparse_categorical_crossentropy', # labels provided as integers (not one-hot)
              metrics=['accuracy'])

# %%
# train the network model
history = model.fit(x_train, y_train,
                    epochs=200, validation_split=0.1,
                    shuffle=True, batch_size=200,
                    verbose=1)

# we can also save and/or load a model
#model = tf.keras.models.load_model('spectral_classifier_v2.h5')
#model.save('spectral_classifier_v2.h5')
# Out:
# Epoch 1/200
# 29/29 [==============================] - 5s 90ms/step - loss: 1.2475 - accuracy: 0.3425 - val_loss: 1.0830 - val_accuracy: 0.5857
# Epoch 2/200
# 29/29 [==============================] - 2s 73ms/step - loss: 1.0991 - accuracy: 0.3862 - val_loss: 1.0262 - val_accuracy: 0.5587
# Epoch 3/200
# 29/29 [==============================] - 2s 74ms/step - loss: 0.9538 - accuracy: 0.5049 - val_loss: 0.7437 - val_accuracy: 0.6016
# Epoch 4/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.7448 - accuracy: 0.5884 - val_loss: 0.6372 - val_accuracy: 0.6683
# Epoch 5/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.6922 - accuracy: 0.6291 - val_loss: 0.6033 - val_accuracy: 0.6810
# Epoch 6/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.6683 - accuracy: 0.6533 - val_loss: 0.5928 - val_accuracy: 0.6952
# Epoch 7/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.6624 - accuracy: 0.6635 - val_loss: 0.5787 - val_accuracy: 0.7048
# Epoch 8/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.6467 - accuracy: 0.6847 - val_loss: 0.5774 - val_accuracy: 0.7143
# Epoch 9/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.6442 - accuracy: 0.6843 - val_loss: 0.5672 - val_accuracy: 0.7159
# Epoch 10/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.6333 - accuracy: 0.6958 - val_loss: 0.5623 - val_accuracy: 0.7048
# Epoch 11/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.6292 - accuracy: 0.6915 - val_loss: 0.5553 - val_accuracy: 0.7206
# Epoch 12/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.6283 - accuracy: 0.6952 - val_loss: 0.5529 - val_accuracy: 0.7143
# Epoch 13/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.6099 - accuracy: 0.7071 - val_loss: 0.5415 - val_accuracy: 0.7381
# Epoch 14/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.6173 - accuracy: 0.7004 - val_loss: 0.5391 - val_accuracy: 0.7444
# Epoch 15/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.6008 - accuracy: 0.7175 - val_loss: 0.5288 - val_accuracy: 0.7333
# Epoch 16/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5942 - accuracy: 0.7152 - val_loss: 0.5202 - val_accuracy: 0.7508
# Epoch 17/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5785 - accuracy: 0.7337 - val_loss: 0.5135 - val_accuracy: 0.7556
# Epoch 18/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.5726 - accuracy: 0.7310 - val_loss: 0.5057 - val_accuracy: 0.7571
# Epoch 19/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.5654 - accuracy: 0.7392 - val_loss: 0.4969 - val_accuracy: 0.7571
# Epoch 20/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.5535 - accuracy: 0.7409 - val_loss: 0.4847 - val_accuracy: 0.7667
# Epoch 21/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.5436 - accuracy: 0.7469 - val_loss: 0.4821 - val_accuracy: 0.7571
# Epoch 22/200
# 29/29 [==============================] - 2s 73ms/step - loss: 0.5524 - accuracy: 0.7414 - val_loss: 0.4834 - val_accuracy: 0.7683
# Epoch 23/200
# 29/29 [==============================] - 2s 76ms/step - loss: 0.5345 - accuracy: 0.7557 - val_loss: 0.4725 - val_accuracy: 0.7746
# Epoch 24/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.5299 - accuracy: 0.7552 - val_loss: 0.4755 - val_accuracy: 0.7667
# Epoch 25/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.5267 - accuracy: 0.7552 - val_loss: 0.4641 - val_accuracy: 0.7730
# Epoch 26/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.5148 - accuracy: 0.7665 - val_loss: 0.4844 - val_accuracy: 0.7667
# Epoch 27/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.5154 - accuracy: 0.7677 - val_loss: 0.4625 - val_accuracy: 0.7841
# Epoch 28/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5057 - accuracy: 0.7735 - val_loss: 0.4509 - val_accuracy: 0.7937
# Epoch 29/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.5038 - accuracy: 0.7681 - val_loss: 0.4413 - val_accuracy: 0.7937
# Epoch 30/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4893 - accuracy: 0.7852 - val_loss: 0.4516 - val_accuracy: 0.7921
# Epoch 31/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4944 - accuracy: 0.7767 - val_loss: 0.4529 - val_accuracy: 0.7968
# Epoch 32/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4923 - accuracy: 0.7746 - val_loss: 0.4445 - val_accuracy: 0.7984
# Epoch 33/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4855 - accuracy: 0.7813 - val_loss: 0.4511 - val_accuracy: 0.8063
# Epoch 34/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.4882 - accuracy: 0.7868 - val_loss: 0.4224 - val_accuracy: 0.8000
# Epoch 35/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4707 - accuracy: 0.7915 - val_loss: 0.4336 - val_accuracy: 0.7968
# Epoch 36/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.4780 - accuracy: 0.7852 - val_loss: 0.4182 - val_accuracy: 0.8079
# Epoch 37/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4696 - accuracy: 0.7866 - val_loss: 0.4229 - val_accuracy: 0.8016
# Epoch 38/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.4671 - accuracy: 0.7891 - val_loss: 0.4236 - val_accuracy: 0.8079
# Epoch 39/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.4661 - accuracy: 0.7926 - val_loss: 0.4254 - val_accuracy: 0.8238
# Epoch 40/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4575 - accuracy: 0.8035 - val_loss: 0.4106 - val_accuracy: 0.8302
# Epoch 41/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4540 - accuracy: 0.7954 - val_loss: 0.4104 - val_accuracy: 0.8190
# Epoch 42/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4513 - accuracy: 0.8005 - val_loss: 0.4117 - val_accuracy: 0.8159
# Epoch 43/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4497 - accuracy: 0.7984 - val_loss: 0.3984 - val_accuracy: 0.8159
# Epoch 44/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4502 - accuracy: 0.7996 - val_loss: 0.4024 - val_accuracy: 0.8206
# Epoch 45/200
# 29/29 [==============================] - 2s 64ms/step - loss: 0.4409 - accuracy: 0.8088 - val_loss: 0.4120 - val_accuracy: 0.8349
# Epoch 46/200
# 29/29 [==============================] - 2s 66ms/step - loss: 0.4367 - accuracy: 0.8139 - val_loss: 0.3975 - val_accuracy: 0.8238
# Epoch 47/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4383 - accuracy: 0.8041 - val_loss: 0.3957 - val_accuracy: 0.8206
# Epoch 48/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4253 - accuracy: 0.8187 - val_loss: 0.3934 - val_accuracy: 0.8190
# Epoch 49/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4296 - accuracy: 0.8113 - val_loss: 0.3893 - val_accuracy: 0.8286
# Epoch 50/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4257 - accuracy: 0.8132 - val_loss: 0.3890 - val_accuracy: 0.8175
# Epoch 51/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4194 - accuracy: 0.8245 - val_loss: 0.3813 - val_accuracy: 0.8317
# Epoch 52/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4179 - accuracy: 0.8187 - val_loss: 0.3814 - val_accuracy: 0.8397
# Epoch 53/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4209 - accuracy: 0.8150 - val_loss: 0.3704 - val_accuracy: 0.8270
# Epoch 54/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4159 - accuracy: 0.8236 - val_loss: 0.3711 - val_accuracy: 0.8444
# Epoch 55/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4096 - accuracy: 0.8236 - val_loss: 0.3676 - val_accuracy: 0.8302
# Epoch 56/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4091 - accuracy: 0.8215 - val_loss: 0.3781 - val_accuracy: 0.8238
# Epoch 57/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.4044 - accuracy: 0.8219 - val_loss: 0.3750 - val_accuracy: 0.8302
# Epoch 58/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4076 - accuracy: 0.8226 - val_loss: 0.3729 - val_accuracy: 0.8254
# Epoch 59/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.4069 - accuracy: 0.8279 - val_loss: 0.3812 - val_accuracy: 0.8238
# Epoch 60/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.3955 - accuracy: 0.8326 - val_loss: 0.3721 - val_accuracy: 0.8381
# Epoch 61/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3944 - accuracy: 0.8353 - val_loss: 0.3704 - val_accuracy: 0.8365
# Epoch 62/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3939 - accuracy: 0.8291 - val_loss: 0.3616 - val_accuracy: 0.8429
# Epoch 63/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3903 - accuracy: 0.8351 - val_loss: 0.3707 - val_accuracy: 0.8238
# Epoch 64/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3893 - accuracy: 0.8346 - val_loss: 0.3699 - val_accuracy: 0.8476
# Epoch 65/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3821 - accuracy: 0.8353 - val_loss: 0.3659 - val_accuracy: 0.8286
# Epoch 66/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3840 - accuracy: 0.8332 - val_loss: 0.3557 - val_accuracy: 0.8286
# Epoch 67/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3840 - accuracy: 0.8354 - val_loss: 0.3590 - val_accuracy: 0.8333
# Epoch 68/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3841 - accuracy: 0.8372 - val_loss: 0.3725 - val_accuracy: 0.8381
# Epoch 69/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3737 - accuracy: 0.8404 - val_loss: 0.3631 - val_accuracy: 0.8476
# Epoch 70/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3844 - accuracy: 0.8372 - val_loss: 0.3577 - val_accuracy: 0.8444
# Epoch 71/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3745 - accuracy: 0.8437 - val_loss: 0.3490 - val_accuracy: 0.8571
# Epoch 72/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.3673 - accuracy: 0.8406 - val_loss: 0.3547 - val_accuracy: 0.8492
# Epoch 73/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3774 - accuracy: 0.8434 - val_loss: 0.3491 - val_accuracy: 0.8460
# Epoch 74/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3602 - accuracy: 0.8497 - val_loss: 0.3401 - val_accuracy: 0.8460
# Epoch 75/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3597 - accuracy: 0.8527 - val_loss: 0.3490 - val_accuracy: 0.8413
# Epoch 76/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3597 - accuracy: 0.8517 - val_loss: 0.3389 - val_accuracy: 0.8492
# Epoch 77/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3673 - accuracy: 0.8448 - val_loss: 0.3425 - val_accuracy: 0.8603
# Epoch 78/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3636 - accuracy: 0.8429 - val_loss: 0.3392 - val_accuracy: 0.8492
# Epoch 79/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3592 - accuracy: 0.8481 - val_loss: 0.3438 - val_accuracy: 0.8540
# Epoch 80/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3557 - accuracy: 0.8497 - val_loss: 0.3402 - val_accuracy: 0.8571
# Epoch 81/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3515 - accuracy: 0.8547 - val_loss: 0.3364 - val_accuracy: 0.8571
# Epoch 82/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3504 - accuracy: 0.8504 - val_loss: 0.3326 - val_accuracy: 0.8603
# Epoch 83/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3500 - accuracy: 0.8577 - val_loss: 0.3514 - val_accuracy: 0.8349
# Epoch 84/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3488 - accuracy: 0.8490 - val_loss: 0.3411 - val_accuracy: 0.8460
# Epoch 85/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3504 - accuracy: 0.8571 - val_loss: 0.3349 - val_accuracy: 0.8571
# Epoch 86/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3437 - accuracy: 0.8598 - val_loss: 0.3378 - val_accuracy: 0.8413
# Epoch 87/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3430 - accuracy: 0.8524 - val_loss: 0.3387 - val_accuracy: 0.8508
# Epoch 88/200
# 29/29 [==============================] - 2s 66ms/step - loss: 0.3531 - accuracy: 0.8519 - val_loss: 0.3382 - val_accuracy: 0.8508
# Epoch 89/200
# 29/29 [==============================] - 2s 75ms/step - loss: 0.3442 - accuracy: 0.8511 - val_loss: 0.3320 - val_accuracy: 0.8524
# Epoch 90/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3437 - accuracy: 0.8547 - val_loss: 0.3319 - val_accuracy: 0.8635
# Epoch 91/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3489 - accuracy: 0.8524 - val_loss: 0.3389 - val_accuracy: 0.8524
# Epoch 92/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3330 - accuracy: 0.8670 - val_loss: 0.3374 - val_accuracy: 0.8429
# Epoch 93/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.3295 - accuracy: 0.8642 - val_loss: 0.3409 - val_accuracy: 0.8492
# Epoch 94/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.3423 - accuracy: 0.8526 - val_loss: 0.3323 - val_accuracy: 0.8619
# Epoch 95/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3284 - accuracy: 0.8640 - val_loss: 0.3283 - val_accuracy: 0.8603
# Epoch 96/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3194 - accuracy: 0.8644 - val_loss: 0.3302 - val_accuracy: 0.8476
# Epoch 97/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.3324 - accuracy: 0.8543 - val_loss: 0.3442 - val_accuracy: 0.8524
# Epoch 98/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3302 - accuracy: 0.8663 - val_loss: 0.3293 - val_accuracy: 0.8571
# Epoch 99/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3275 - accuracy: 0.8601 - val_loss: 0.3337 - val_accuracy: 0.8524
# Epoch 100/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3243 - accuracy: 0.8681 - val_loss: 0.3298 - val_accuracy: 0.8571
# Epoch 101/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3280 - accuracy: 0.8665 - val_loss: 0.3395 - val_accuracy: 0.8397
# Epoch 102/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3246 - accuracy: 0.8653 - val_loss: 0.3214 - val_accuracy: 0.8651
# Epoch 103/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.3239 - accuracy: 0.8616 - val_loss: 0.3329 - val_accuracy: 0.8492
# Epoch 104/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3292 - accuracy: 0.8598 - val_loss: 0.3284 - val_accuracy: 0.8524
# Epoch 105/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3268 - accuracy: 0.8605 - val_loss: 0.3241 - val_accuracy: 0.8667
# Epoch 106/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3227 - accuracy: 0.8704 - val_loss: 0.3274 - val_accuracy: 0.8571
# Epoch 107/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3219 - accuracy: 0.8702 - val_loss: 0.3249 - val_accuracy: 0.8508
# Epoch 108/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3211 - accuracy: 0.8674 - val_loss: 0.3237 - val_accuracy: 0.8476
# Epoch 109/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3079 - accuracy: 0.8693 - val_loss: 0.3167 - val_accuracy: 0.8524
# Epoch 110/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3186 - accuracy: 0.8670 - val_loss: 0.3205 - val_accuracy: 0.8508
# Epoch 111/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3026 - accuracy: 0.8755 - val_loss: 0.3191 - val_accuracy: 0.8587
# Epoch 112/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3113 - accuracy: 0.8741 - val_loss: 0.3204 - val_accuracy: 0.8571
# Epoch 113/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3073 - accuracy: 0.8732 - val_loss: 0.3206 - val_accuracy: 0.8444
# Epoch 114/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.3095 - accuracy: 0.8651 - val_loss: 0.3107 - val_accuracy: 0.8651
# Epoch 115/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.3060 - accuracy: 0.8695 - val_loss: 0.3092 - val_accuracy: 0.8619
# Epoch 116/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.3111 - accuracy: 0.8711 - val_loss: 0.3159 - val_accuracy: 0.8492
# Epoch 117/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.3029 - accuracy: 0.8741 - val_loss: 0.3067 - val_accuracy: 0.8683
# Epoch 118/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.3075 - accuracy: 0.8744 - val_loss: 0.3100 - val_accuracy: 0.8492
# Epoch 119/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.2995 - accuracy: 0.8735 - val_loss: 0.3088 - val_accuracy: 0.8651
# Epoch 120/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.3056 - accuracy: 0.8686 - val_loss: 0.3132 - val_accuracy: 0.8492
# Epoch 121/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.3055 - accuracy: 0.8771 - val_loss: 0.3054 - val_accuracy: 0.8603
# Epoch 122/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.3059 - accuracy: 0.8714 - val_loss: 0.3141 - val_accuracy: 0.8587
# Epoch 123/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.2958 - accuracy: 0.8813 - val_loss: 0.3082 - val_accuracy: 0.8540
# Epoch 124/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.2983 - accuracy: 0.8771 - val_loss: 0.3053 - val_accuracy: 0.8667
# Epoch 125/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.2918 - accuracy: 0.8767 - val_loss: 0.3038 - val_accuracy: 0.8683
# Epoch 126/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.2946 - accuracy: 0.8762 - val_loss: 0.3157 - val_accuracy: 0.8571
# Epoch 127/200
# 29/29 [==============================] - 2s 73ms/step - loss: 0.2968 - accuracy: 0.8744 - val_loss: 0.3093 - val_accuracy: 0.8683
# Epoch 128/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.2963 - accuracy: 0.8762 - val_loss: 0.3154 - val_accuracy: 0.8508
# Epoch 129/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.3049 - accuracy: 0.8767 - val_loss: 0.3099 - val_accuracy: 0.8619
# Epoch 130/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.2879 - accuracy: 0.8765 - val_loss: 0.3214 - val_accuracy: 0.8508
# Epoch 131/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.2934 - accuracy: 0.8725 - val_loss: 0.3102 - val_accuracy: 0.8508
# Epoch 132/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.2880 - accuracy: 0.8832 - val_loss: 0.3054 - val_accuracy: 0.8683
# Epoch 133/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.2838 - accuracy: 0.8832 - val_loss: 0.3101 - val_accuracy: 0.8683
# Epoch 134/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.2892 - accuracy: 0.8769 - val_loss: 0.3142 - val_accuracy: 0.8556
# Epoch 135/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.2951 - accuracy: 0.8750 - val_loss: 0.3098 - val_accuracy: 0.8603
# Epoch 136/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.2939 - accuracy: 0.8792 - val_loss: 0.3106 - val_accuracy: 0.8524
# Epoch 137/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.2829 - accuracy: 0.8817 - val_loss: 0.3064 - val_accuracy: 0.8667
# Epoch 138/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2913 - accuracy: 0.8790 - val_loss: 0.3144 - val_accuracy: 0.8635
# Epoch 139/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2782 - accuracy: 0.8850 - val_loss: 0.3078 - val_accuracy: 0.8667
# Epoch 140/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2850 - accuracy: 0.8829 - val_loss: 0.3121 - val_accuracy: 0.8603
# Epoch 141/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2825 - accuracy: 0.8815 - val_loss: 0.3055 - val_accuracy: 0.8651
# Epoch 142/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2846 - accuracy: 0.8808 - val_loss: 0.2976 - val_accuracy: 0.8683
# Epoch 143/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2768 - accuracy: 0.8857 - val_loss: 0.3029 - val_accuracy: 0.8667
# Epoch 144/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2764 - accuracy: 0.8848 - val_loss: 0.3007 - val_accuracy: 0.8683
# Epoch 145/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2738 - accuracy: 0.8859 - val_loss: 0.3221 - val_accuracy: 0.8635
# Epoch 146/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2849 - accuracy: 0.8820 - val_loss: 0.2986 - val_accuracy: 0.8698
# Epoch 147/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2806 - accuracy: 0.8859 - val_loss: 0.3027 - val_accuracy: 0.8635
# Epoch 148/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.2792 - accuracy: 0.8866 - val_loss: 0.2990 - val_accuracy: 0.8698
# Epoch 149/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2838 - accuracy: 0.8801 - val_loss: 0.2993 - val_accuracy: 0.8651
# Epoch 150/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2819 - accuracy: 0.8887 - val_loss: 0.3057 - val_accuracy: 0.8651
# Epoch 151/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2697 - accuracy: 0.8907 - val_loss: 0.2973 - val_accuracy: 0.8714
# Epoch 152/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2708 - accuracy: 0.8887 - val_loss: 0.3110 - val_accuracy: 0.8587
# Epoch 153/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2738 - accuracy: 0.8852 - val_loss: 0.3007 - val_accuracy: 0.8619
# Epoch 154/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2640 - accuracy: 0.8949 - val_loss: 0.3022 - val_accuracy: 0.8683
# Epoch 155/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.2601 - accuracy: 0.8908 - val_loss: 0.3111 - val_accuracy: 0.8619
# Epoch 156/200
# 29/29 [==============================] - 2s 66ms/step - loss: 0.2748 - accuracy: 0.8914 - val_loss: 0.2978 - val_accuracy: 0.8730
# Epoch 157/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.2711 - accuracy: 0.8878 - val_loss: 0.2974 - val_accuracy: 0.8746
# Epoch 158/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.2685 - accuracy: 0.8889 - val_loss: 0.3048 - val_accuracy: 0.8667
# Epoch 159/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.2721 - accuracy: 0.8834 - val_loss: 0.2994 - val_accuracy: 0.8651
# Epoch 160/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2697 - accuracy: 0.8905 - val_loss: 0.3042 - val_accuracy: 0.8603
# Epoch 161/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.2638 - accuracy: 0.8938 - val_loss: 0.2950 - val_accuracy: 0.8698
# Epoch 162/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2639 - accuracy: 0.8907 - val_loss: 0.2996 - val_accuracy: 0.8730
# Epoch 163/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2679 - accuracy: 0.8866 - val_loss: 0.2992 - val_accuracy: 0.8683
# Epoch 164/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2497 - accuracy: 0.8975 - val_loss: 0.2987 - val_accuracy: 0.8698
# Epoch 165/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2752 - accuracy: 0.8884 - val_loss: 0.3231 - val_accuracy: 0.8460
# Epoch 166/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2553 - accuracy: 0.8896 - val_loss: 0.3178 - val_accuracy: 0.8492
# Epoch 167/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2574 - accuracy: 0.8924 - val_loss: 0.3033 - val_accuracy: 0.8667
# Epoch 168/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2508 - accuracy: 0.8998 - val_loss: 0.2984 - val_accuracy: 0.8635
# Epoch 169/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2563 - accuracy: 0.8952 - val_loss: 0.3048 - val_accuracy: 0.8619
# Epoch 170/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2412 - accuracy: 0.9019 - val_loss: 0.2895 - val_accuracy: 0.8714
# Epoch 171/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2475 - accuracy: 0.8956 - val_loss: 0.2986 - val_accuracy: 0.8683
# Epoch 172/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2565 - accuracy: 0.8958 - val_loss: 0.2987 - val_accuracy: 0.8714
# Epoch 173/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2572 - accuracy: 0.8931 - val_loss: 0.3073 - val_accuracy: 0.8603
# Epoch 174/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.2523 - accuracy: 0.8991 - val_loss: 0.3000 - val_accuracy: 0.8683
# Epoch 175/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.2534 - accuracy: 0.9012 - val_loss: 0.3013 - val_accuracy: 0.8603
# Epoch 176/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2535 - accuracy: 0.8951 - val_loss: 0.2937 - val_accuracy: 0.8683
# Epoch 177/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2531 - accuracy: 0.8945 - val_loss: 0.3011 - val_accuracy: 0.8683
# Epoch 178/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2550 - accuracy: 0.8972 - val_loss: 0.2998 - val_accuracy: 0.8746
# Epoch 179/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2542 - accuracy: 0.8963 - val_loss: 0.2992 - val_accuracy: 0.8714
# Epoch 180/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2491 - accuracy: 0.8988 - val_loss: 0.2981 - val_accuracy: 0.8730
# Epoch 181/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2484 - accuracy: 0.8989 - val_loss: 0.2917 - val_accuracy: 0.8762
# Epoch 182/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2569 - accuracy: 0.8952 - val_loss: 0.3106 - val_accuracy: 0.8683
# Epoch 183/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2516 - accuracy: 0.8968 - val_loss: 0.2971 - val_accuracy: 0.8730
# Epoch 184/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2581 - accuracy: 0.8898 - val_loss: 0.2924 - val_accuracy: 0.8730
# Epoch 185/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2610 - accuracy: 0.8910 - val_loss: 0.2888 - val_accuracy: 0.8778
# Epoch 186/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2467 - accuracy: 0.8975 - val_loss: 0.2952 - val_accuracy: 0.8746
# Epoch 187/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.2504 - accuracy: 0.8919 - val_loss: 0.2928 - val_accuracy: 0.8730
# Epoch 188/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2528 - accuracy: 0.8961 - val_loss: 0.2942 - val_accuracy: 0.8698
# Epoch 189/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.2466 - accuracy: 0.9000 - val_loss: 0.2926 - val_accuracy: 0.8762
# Epoch 190/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2478 - accuracy: 0.8956 - val_loss: 0.2966 - val_accuracy: 0.8698
# Epoch 191/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.2493 - accuracy: 0.8958 - val_loss: 0.2888 - val_accuracy: 0.8667
# Epoch 192/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.2549 - accuracy: 0.8958 - val_loss: 0.2891 - val_accuracy: 0.8746
# Epoch 193/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2454 - accuracy: 0.8972 - val_loss: 0.2899 - val_accuracy: 0.8778
# Epoch 194/200
# 29/29 [==============================] - 2s 65ms/step - loss: 0.2354 - accuracy: 0.9035 - val_loss: 0.2897 - val_accuracy: 0.8667
# Epoch 195/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.2364 - accuracy: 0.9039 - val_loss: 0.2996 - val_accuracy: 0.8698
# Epoch 196/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2420 - accuracy: 0.8968 - val_loss: 0.2914 - val_accuracy: 0.8714
# Epoch 197/200
# 29/29 [==============================] - 2s 66ms/step - loss: 0.2297 - accuracy: 0.9048 - val_loss: 0.2898 - val_accuracy: 0.8714
# Epoch 198/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2343 - accuracy: 0.9018 - val_loss: 0.2942 - val_accuracy: 0.8714
# Epoch 199/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2332 - accuracy: 0.9044 - val_loss: 0.2956 - val_accuracy: 0.8683
# Epoch 200/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.2353 - accuracy: 0.9021 - val_loss: 0.3085 - val_accuracy: 0.8587

# %% [markdown]
# ## 5) Monitor the training

# %%
def plot_accuracy(name, ylim=[0,1.01]):
    #plt.plot(history.history['acc'])
    plt.plot(history.history['accuracy'])
    #plt.plot(history.history['val_acc'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.ylim(ylim[0], ylim[1])
    plt.legend(['training', 'validation'], loc='upper left')
    plt.savefig(name)
    plt.show()

# %%
def plot_loss(name, ylim=[0,2]):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.ylim(ylim[0],ylim[1])
    plt.legend(['training', 'validation'], loc='upper left')
    plt.savefig(name)
    plt.show()

# %%
plot_accuracy("accuracy_graph_goldbig.png")
plot_loss("loss_graph_goldbig.png")

# %% [markdown]
# ## Test the network model - predictive performance

# %%
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

# %%
# predict on the test data
predictions = model.predict(x=x_test)
rounded_predictions = np.argmax(predictions, axis=-1)

class_names = ['AGN','galaxy','QSO','star']
# Out:
# 22/22 [==============================] - 0s 6ms/step

# %% [markdown]
# ### Confusion Matrix

# %%
def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm = confusion_matrix(y_true=y_test, y_pred=rounded_predictions)
plot_confusion_matrix(cm=cm, classes=class_names, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[227  12   3]
#  [ 45 200   2]
#  [  9   3 199]]

# %% [markdown]
# ## Confusion matrix (percentage)

# %%
cm = confusion_matrix(y_true=y_test, y_pred=rounded_predictions)
cm_shape = np.shape(cm)

cm_percentages = np.zeros(shape=cm_shape)
for i in range(cm_shape[0]):
    total_objects = sum(cm[i])
    
    for t in range(cm_shape[0]):
        number_guessed = cm[i][t]
        cm_percentages[i][t] = round(number_guessed/total_objects*100,2)

plot_confusion_matrix(cm=cm_percentages, classes=class_names, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[93.8   4.96  1.24]
#  [18.22 80.97  0.81]
#  [ 4.27  1.42 94.31]]

# %% [markdown]
# ## Class-wise accuracy

# %%
class_accuaracy = []

for i in range(cm_shape[0]):
    total_objects = sum(cm[i])
    correct_guesses = cm[i][i]
    class_accuaracy.append(correct_guesses/total_objects)
    
print("Accuracy for class")
for i in range(cm_shape[0]):
    print(class_names[i], "\t:", round(class_accuaracy[i],4)*100, "%")
# Out:
# Accuracy for class
# AGN 	: 93.8 %
# galaxy 	: 80.97 %
# QSO 	: 94.31 %

# %% [markdown]
# ## Having a look at false predictions

# %% [markdown]
# **Label 0 = AGN** \
# **Label 1 = galaxy** \
# **Label 2 = QSO** \
# **Label 3 = star**

# %%
predictions = model.predict(x=x_test)
rounded_predictions = np.argmax(predictions, axis=-1)

wrong_predictions = []

for i in range(len(rounded_predictions)):
    if rounded_predictions[i] != y_test[i]:
        wrong_predictions.append(numbers_test[i])      

wrong_predictions.sort()
        
print(len(rounded_predictions), "right")
print(len(wrong_predictions), "false")
print(str(((len(rounded_predictions)-len(wrong_predictions))/len(rounded_predictions))*100) + "% correctly classified")
# Out:
# 22/22 [==============================] - 0s 5ms/step
# 700 right
# 74 false
# 89.42857142857143% correctly classified

# %%
for i in wrong_predictions:  
    plt.plot(wavelengths, data[i]) 
    plt.xlabel('wavelength(Å)') 
    plt.ylabel('flux (10-17 ergs/s/cm2/Å)') 
    plt.grid(True)
    plt.title(str(i))
    plt.show()

# %% [markdown]
# ## Simple benchmarking with the scikit-learn package

# %%
# SVM support vector machine
# see: https://scikit-learn.org/stable/modules/svm.html
from sklearn import svm
clf = svm.SVC(gamma=0.001, C=100.)
clf.fit(data_training, labels_training)
clf.score(data_test, labels_test)
# Out:
# 0.39285714285714285

# %%
# Random forest
# see: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
from sklearn.ensemble import RandomForestClassifier
clf2 = RandomForestClassifier(n_estimators=100, random_state=123)
clf2.fit(data_training, labels_training)
clf2.score(data_test, labels_test)
# Out:
# 0.7871428571428571

# %%
# Logistic regression
# see: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
from sklearn.linear_model import LogisticRegression
clf1 = LogisticRegression(max_iter=10000, random_state=123)
clf1.fit(data_training, labels_training)
clf1.score(data_test, labels_test)
# Out:
# 0.8571428571428571

# %%
# Gaussian naive Bayes
# see: https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html
from sklearn.naive_bayes import GaussianNB
clf3 = GaussianNB()
clf3.fit(data_training, labels_training)
clf3.score(data_test, labels_test)
# Out:
# 0.5014285714285714
